# %% [markdown]
# # Import IgLM

# %%
from iglm import IgLM
from anarci import anarci

from functools import reduce
from operator import concat
import numpy as np
import pickle
import collections
import matplotlib.pyplot as plt

iglm = IgLM()

# %% [markdown]
# # Generate Sequences

# %%
# Generate full sequences (no camel)

chain_tokens = ["[HEAVY]", "[LIGHT]"]
species_tokens = ["[HUMAN]", "[MOUSE]", "[RABBIT]", "[RAT]", "[RHESUS]"]
prompt_sequence = [["EVQ","QSA","DIQ"], ["QVQ","QAV","DIV"], ["QEQ","QPA","ALV"], ["EVQ","QAV","GIQ"], ["QVQ","QSV","AIQ"]]
temperature = [0.6, 0.8, 1.0, 1.2]
num_seqs = [2000, 1000]

generated_seqs = []
names = []
for t in temperature:
    for i in species_tokens:
        for j in chain_tokens:
            if j == "[HEAVY]":
                generated_seqs.append(iglm.generate(j, i, 
                                    prompt_sequence=prompt_sequence[species_tokens.index(i)][chain_tokens.index(j)], 
                                    num_to_generate=num_seqs[0], temperature=t))
                for m in range(num_seqs[0]):
                    names.append(f"{i}{m}:{t}:H")
            else:     
                for k in range(1,3,1):
                    generated_seqs.append(iglm.generate(j, i, 
                                        prompt_sequence=prompt_sequence[species_tokens.index(i)][k], 
                                        num_to_generate=num_seqs[1], temperature=t))
                for m in range(2*num_seqs[1]):
                    if m < num_seqs[1]:
                        names.append(f"{i}{m}:{t}:L")
                    else:
                        m -= num_seqs[1]
                        names.append(f"{i}{m}:{t}:K")

    # Add camel sequence
    generated_seqs.append(iglm.generate("[HEAVY]", "[CAMEL]", 
                        prompt_sequence="QVQ", num_to_generate=num_seqs[0], temperature=t))

    for m in range(num_seqs[0]):
        names.append(f"[CAMEL]{m}:{t}:H")
# Out:
# 100%|███████████████████████████████████████| 2000/2000 [26:07<00:00,  1.28it/s]
# 100%|███████████████████████████████████████| 1000/1000 [20:50<00:00,  1.25s/it]
# 100%|███████████████████████████████████████| 1000/1000 [19:46<00:00,  1.19s/it]
# 100%|███████████████████████████████████████| 2000/2000 [24:28<00:00,  1.36it/s]
# 100%|█████████████████████████████████████| 1000/1000 [3:30:07<00:00, 12.61s/it]
# 100%|███████████████████████████████████████| 1000/1000 [47:58<00:00,  2.88s/it]
# 100%|███████████████████████████████████████| 2000/2000 [38:59<00:00,  1.17s/it]
# 100%|███████████████████████████████████████| 1000/1000 [12:54<00:00,  1.29it/s]
# 100%|███████████████████████████████████████| 1000/1000 [10:24<00:00,  1.60it/s]
# 100%|███████████████████████████████████████| 2000/2000 [27:38<00:00,  1.21it/s]
# 100%|███████████████████████████████████████| 1000/1000 [12:07<00:00,  1.37it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:24<00:00,  1.46it/s]
# 100%|███████████████████████████████████████| 2000/2000 [24:22<00:00,  1.37it/s]
# 100%|███████████████████████████████████████| 1000/1000 [13:51<00:00,  1.20it/s]
# 100%|███████████████████████████████████████| 1000/1000 [21:27<00:00,  1.29s/it]
# 100%|███████████████████████████████████████| 2000/2000 [25:18<00:00,  1.32it/s]
# 100%|███████████████████████████████████████| 2000/2000 [25:04<00:00,  1.33it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:14<00:00,  1.48it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:08<00:00,  1.50it/s]
# 100%|███████████████████████████████████████| 2000/2000 [24:10<00:00,  1.38it/s]
# 100%|███████████████████████████████████████| 1000/1000 [22:08<00:00,  1.33s/it]
# 100%|███████████████████████████████████████| 1000/1000 [15:28<00:00,  1.08it/s]
# 100%|███████████████████████████████████████| 2000/2000 [28:20<00:00,  1.18it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:12<00:00,  1.49it/s]
# 100%|███████████████████████████████████████| 1000/1000 [10:29<00:00,  1.59it/s]
# 100%|███████████████████████████████████████| 2000/2000 [24:46<00:00,  1.35it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:18<00:00,  1.47it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:38<00:00,  1.43it/s]
# 100%|█████████████████████████████████████| 2000/2000 [1:04:36<00:00,  1.94s/it]
# 100%|███████████████████████████████████████| 1000/1000 [11:57<00:00,  1.39it/s]
# 100%|███████████████████████████████████████| 1000/1000 [12:58<00:00,  1.28it/s]
# 100%|███████████████████████████████████████| 2000/2000 [27:49<00:00,  1.20it/s]
# 100%|███████████████████████████████████████| 2000/2000 [32:15<00:00,  1.03it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:30<00:00,  1.45it/s]
# 100%|█████████████████████████████████████| 1000/1000 [1:28:50<00:00,  5.33s/it]
# 100%|███████████████████████████████████████| 2000/2000 [30:33<00:00,  1.09it/s]
# 100%|███████████████████████████████████████| 1000/1000 [21:30<00:00,  1.29s/it]
# 100%|███████████████████████████████████████| 1000/1000 [20:19<00:00,  1.22s/it]
# 100%|███████████████████████████████████████| 2000/2000 [48:41<00:00,  1.46s/it]
# 100%|███████████████████████████████████████| 1000/1000 [18:19<00:00,  1.10s/it]
# 100%|███████████████████████████████████████| 1000/1000 [17:36<00:00,  1.06s/it]
# 100%|███████████████████████████████████████| 2000/2000 [37:33<00:00,  1.13s/it]
# 100%|███████████████████████████████████████| 1000/1000 [10:43<00:00,  1.55it/s]
# 100%|███████████████████████████████████████| 1000/1000 [10:31<00:00,  1.58it/s]
# 100%|███████████████████████████████████████| 2000/2000 [29:56<00:00,  1.11it/s]
# 100%|███████████████████████████████████████| 1000/1000 [36:14<00:00,  2.17s/it]
# 100%|███████████████████████████████████████| 1000/1000 [19:10<00:00,  1.15s/it]
# 100%|███████████████████████████████████████| 2000/2000 [25:31<00:00,  1.31it/s]
# 100%|███████████████████████████████████████| 2000/2000 [24:55<00:00,  1.34it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:11<00:00,  1.49it/s]
# 100%|███████████████████████████████████████| 1000/1000 [10:46<00:00,  1.55it/s]
# 100%|███████████████████████████████████████| 2000/2000 [24:40<00:00,  1.35it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:09<00:00,  1.49it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:21<00:00,  1.47it/s]
# 100%|███████████████████████████████████████| 2000/2000 [25:06<00:00,  1.33it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:41<00:00,  1.42it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:28<00:00,  1.45it/s]
# 100%|█████████████████████████████████████| 2000/2000 [1:26:31<00:00,  2.60s/it]
# 100%|███████████████████████████████████████| 1000/1000 [11:12<00:00,  1.49it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:00<00:00,  1.51it/s]
# 100%|███████████████████████████████████████| 2000/2000 [25:04<00:00,  1.33it/s]
# 100%|███████████████████████████████████████| 1000/1000 [11:19<00:00,  1.47it/s]
# 100%|███████████████████████████████████████| 1000/1000 [10:50<00:00,  1.54it/s]
# 100%|███████████████████████████████████████| 2000/2000 [25:28<00:00,  1.31it/s]

# %% [markdown]
# # Analysis

# %%
flattened_seqs = reduce(concat, generated_seqs)

# %%
anarci_sequences = []
for i in range(len(flattened_seqs)):
    anarci_sequences.append((names[i], flattened_seqs[i]))

# %%
results = anarci(anarci_sequences, scheme="imgt", output=False)
numbering, alignment_details, hit_tables = results

# %%
# Save the generated_seqs list
file_name = "generated_seqs.pkl"

open_file = open(file_name, "wb")
pickle.dump(generated_seqs, open_file)
open_file.close()


# Save the names list
file_name = "names.pkl"

open_file = open(file_name, "wb")
pickle.dump(names, open_file)
open_file.close()


# Save the flattened_seqs list
file_name = "flattened_seqs.pkl"

open_file = open(file_name, "wb")
pickle.dump(flattened_seqs, open_file)
open_file.close()


# Save the anarci results
file_name = "anarci_res.pkl"

open_file = open(file_name, "wb")
pickle.dump(results, open_file)
open_file.close()

# %%
# Reopen lists
# open_file = open(file_name, "rb")
# loaded_seqs = pickle.load(open_file)
# open_file.close()

# print(loaded_seqs[0])

# %% [markdown]
# ## Checking for partial match: species ONLY

# %%
label = []
for i in range(len(flattened_seqs)):
    if numbering[i] is None:
        label.append(np.nan)
    else:
        label.append(alignment_details[i][0].get("id"))

# %%
# Initialize different species types

human_H = []
human_L = []

mouse_H = []
mouse_L = []

alpaca_H = []

rabbit_H = []
rabbit_L = []

pig_H = []
pig_L = []

rhesus_H = []
rhesus_L = []

cow_H = []
cow_L = []

rat_H = []
rat_L = []


# Organize by tokens
chain_tokens = ['H', 'L']
species_tokens = ["[HUMAN]", "[MOUSE]", "[CAMEL]", "[RABBIT]", "[RAT]", "[RHESUS]"]

for i in species_tokens:
    for j in chain_tokens:
        human = np.zeros(4)
        mouse = np.zeros(4)
        alpaca = np.zeros(4)
        rabbit = np.zeros(4)
        pig = np.zeros(4)
        rhesus = np.zeros(4)
        cow = np.zeros(4)
        rat = np.zeros(4)
        for t in temperature:
            
            keys = []
            
            if j == 'H':
                start = names.index(f"{i}0:{t}:{j}")
                end = names.index(f"{i}1999:{t}:{j}")
                
                # getting the elements frequencies using Counter class
                elements_count = collections.Counter(label[start:end])
                vals = np.fromiter(elements_count.values(), dtype=int)
                
                for key in elements_count.keys():
                    if type(key) != float:
                        keys.append(key)
                    else:
                        continue
                
                for k in range(len(keys)):
                    keys[k] = keys[k][0:-2]
                    
                for s in set(keys):
                    indices = [i for i, x in enumerate(keys) if x == s]
                    if s == 'human':
                        human[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                    elif s == 'mouse':
                        mouse[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                    elif s == 'alpaca':
                        alpaca[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                    elif s == 'rabbit':
                        rabbit[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                    elif s == 'pig':
                        pig[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                    elif s == 'rhesus':
                        rhesus[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                    elif s == 'cow':
                        cow[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                    elif s == 'rat':
                        rat[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                    
            else:
                if i == "[CAMEL]":
                    continue
                else:
                    start = names.index(f"{i}0:{t}:{j}")
                    end = names.index(f"{i}999:{t}:K")
                
                    # getting the elements frequencies using Counter class
                    elements_count = collections.Counter(label[start:end])
                    vals = np.fromiter(elements_count.values(), dtype=int)
                    for key in elements_count.keys():
                        if type(key) != float:
                            keys.append(key)
                        else:
                            continue
                    for k in range(len(keys)):
                        keys[k] = keys[k][0:-2]
                
                    for s in set(keys):
                        indices = [i for i, x in enumerate(keys) if x == s]
                        if s == 'human':
                            human[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                        elif s == 'mouse':
                            mouse[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                        elif s == 'alpaca':
                            alpaca[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                        elif s == 'rabbit':
                            rabbit[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                        elif s == 'pig':
                            pig[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                        elif s == 'rhesus':
                            rhesus[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                        elif s == 'cow':
                            cow[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
                        elif s == 'rat':
                            rat[temperature.index(t)] = (sum(vals[indices]) / sum(vals)) * 100
            
        if j == 'H':
            human_H.append(human)
            mouse_H.append(mouse)
            alpaca_H.append(alpaca)
            rabbit_H.append(rabbit)
            pig_H.append(pig)
            rhesus_H.append(rhesus)
            cow_H.append(cow)
            rat_H.append(rat)
        else:
            human_L.append(human)
            mouse_L.append(mouse)
            rabbit_L.append(rabbit)
            pig_L.append(pig)
            rhesus_L.append(rhesus)
            cow_L.append(cow)
            rat_L.append(rat)

# %%
human_H
# Out:
# [array([ 2.45122561,  5.85292646,  9.15457729, 13.35667834]),
#  array([0.05002501, 0.75037519, 0.8004002 , 2.60130065]),
#  array([0.       , 0.       , 0.       , 0.4002001]),
#  array([0., 0., 0., 0.]),
#  array([0.        , 0.        , 0.05002501, 0.25012506]),
#  array([34.66733367, 32.66633317, 30.71535768, 36.46823412])]

# %%
fig, axs = plt.subplots(2, 3, figsize=(10,4))
fig.tight_layout()

# [HUMAN] conditioning tag

# [HEAVY] conditioning tag
axs[0, 0].plot(temperature, human_H[0], marker='o', markersize=4, color='dodgerblue', label='human')
axs[0, 0].plot(temperature, mouse_H[0], marker='o', markersize=4, color='darkorange', label='mouse')
axs[0, 0].plot(temperature, alpaca_H[0], marker='o', markersize=4, color='limegreen', label='alpaca')
axs[0, 0].plot(temperature, rabbit_H[0], marker='o', markersize=4, color='orangered', label='rabbit')
axs[0, 0].plot(temperature, pig_H[0], marker='o', markersize=4, color='mediumpurple', label='pig')
axs[0, 0].plot(temperature, rhesus_H[0], marker='o', markersize=4, color='saddlebrown', label='rhesus')
axs[0, 0].plot(temperature, cow_H[0], marker='o', markersize=4, color='hotpink', label='cow')
axs[0, 0].plot(temperature, rat_H[0], marker='o', markersize=4, color='dimgrey', label='rat')

# [LIGHT] conditioning tag
axs[0, 0].plot(temperature, human_L[0], marker='o', markersize=4, linestyle='dashed', color='dodgerblue')
axs[0, 0].plot(temperature, mouse_L[0], marker='o', markersize=4, linestyle='dashed', color='darkorange')
axs[0, 0].plot(temperature, rabbit_L[0], marker='o', markersize=4, linestyle='dashed', color='orangered')
axs[0, 0].plot(temperature, pig_L[0], marker='o', markersize=4, linestyle='dashed', color='mediumpurple')
axs[0, 0].plot(temperature, rhesus_L[0], marker='o', markersize=4, linestyle='dashed', color='saddlebrown')
axs[0, 0].plot(temperature, cow_L[0], marker='o', markersize=4, linestyle='dashed', color='hotpink')
axs[0, 0].plot(temperature, rat_L[0], marker='o', markersize=4, linestyle='dashed', color='dimgrey')

axs[0, 0].set_title('[HUMAN]')
axs[0, 0].set_xticks([0.6, 0.8, 1.0, 1.2])


# [MOUSE] conditioning tag

# [HEAVY] conditioning tag
axs[0, 1].plot(temperature, human_H[1], marker='o', markersize=4, color='dodgerblue')
axs[0, 1].plot(temperature, mouse_H[1], marker='o', markersize=4, color='darkorange')
axs[0, 1].plot(temperature, alpaca_H[1], marker='o', markersize=4, color='limegreen')
axs[0, 1].plot(temperature, rabbit_H[1], marker='o', markersize=4, color='orangered')
axs[0, 1].plot(temperature, pig_H[1], marker='o', markersize=4, color='mediumpurple')
axs[0, 1].plot(temperature, rhesus_H[1], marker='o', markersize=4, color='saddlebrown')
axs[0, 1].plot(temperature, cow_H[1], marker='o', markersize=4, color='hotpink')
axs[0, 1].plot(temperature, rat_H[1], marker='o', markersize=4, color='dimgrey')

# [LIGHT] conditioning tag
axs[0, 1].plot(temperature, human_L[1], marker='o', markersize=4, linestyle='dashed', color='dodgerblue')
axs[0, 1].plot(temperature, mouse_L[1], marker='o', markersize=4, linestyle='dashed', color='darkorange')
axs[0, 1].plot(temperature, rabbit_L[1], marker='o', markersize=4, linestyle='dashed', color='orangered')
axs[0, 1].plot(temperature, pig_L[1], marker='o', markersize=4, linestyle='dashed', color='mediumpurple')
axs[0, 1].plot(temperature, rhesus_L[1], marker='o', markersize=4, linestyle='dashed', color='saddlebrown')
axs[0, 1].plot(temperature, cow_L[1], marker='o', markersize=4, linestyle='dashed', color='hotpink')
axs[0, 1].plot(temperature, rat_L[1], marker='o', markersize=4, linestyle='dashed', color='dimgrey')

axs[0, 1].set_title('[MOUSE]')
axs[0, 1].set_xticks([0.6, 0.8, 1.0, 1.2])

dummy_lines = []
dummy_lines.append(axs[0, 1].plot([],[], c="black", marker='o', markersize=4, ls = '-', label='heavy')[0]) 
dummy_lines.append(axs[0, 1].plot([],[], c="black", marker='o', markersize=4, ls = '--', label='light')[0])                            


# [CAMEL] conditioning tag

# [HEAVY] conditioning tag
axs[0, 2].plot(temperature, human_H[2], marker='o', markersize=4, color='dodgerblue')
axs[0, 2].plot(temperature, mouse_H[2], marker='o', markersize=4, color='darkorange')
axs[0, 2].plot(temperature, alpaca_H[2], marker='o', markersize=4, color='limegreen')
axs[0, 2].plot(temperature, rabbit_H[2], marker='o', markersize=4, color='orangered')
axs[0, 2].plot(temperature, pig_H[2], marker='o', markersize=4, color='mediumpurple')
axs[0, 2].plot(temperature, rhesus_H[2], marker='o', markersize=4, color='saddlebrown')
axs[0, 2].plot(temperature, cow_H[2], marker='o', markersize=4, color='hotpink')
axs[0, 2].plot(temperature, rat_H[2], marker='o', markersize=4, color='dimgrey')

axs[0, 2].set_title('[CAMEL]')
axs[0, 2].set_xticks([0.6, 0.8, 1.0, 1.2])


# [RABBIT] conditioning tag

# [HEAVY] conditioning tag
axs[1, 0].plot(temperature, human_H[3], marker='o', markersize=4, color='dodgerblue')
axs[1, 0].plot(temperature, mouse_H[3], marker='o', markersize=4, color='darkorange')
axs[1, 0].plot(temperature, alpaca_H[3], marker='o', markersize=4, color='limegreen')
axs[1, 0].plot(temperature, rabbit_H[3], marker='o', markersize=4, color='orangered')
axs[1, 0].plot(temperature, pig_H[3], marker='o', markersize=4, color='mediumpurple')
axs[1, 0].plot(temperature, rhesus_H[3], marker='o', markersize=4, color='saddlebrown')
axs[1, 0].plot(temperature, cow_H[3], marker='o', markersize=4, color='hotpink')
axs[1, 0].plot(temperature, rat_H[3], marker='o', markersize=4, color='dimgrey')

# [LIGHT] conditioning tag
axs[1, 0].plot(temperature, human_L[3], marker='o', markersize=4, linestyle='dashed', color='dodgerblue')
axs[1, 0].plot(temperature, mouse_L[3], marker='o', markersize=4, linestyle='dashed', color='darkorange')
axs[1, 0].plot(temperature, rabbit_L[3], marker='o', markersize=4, linestyle='dashed', color='orangered')
axs[1, 0].plot(temperature, pig_L[3], marker='o', markersize=4, linestyle='dashed', color='mediumpurple')
axs[1, 0].plot(temperature, rhesus_L[3], marker='o', markersize=4, linestyle='dashed', color='saddlebrown')
axs[1, 0].plot(temperature, cow_L[3], marker='o', markersize=4, linestyle='dashed', color='hotpink')
axs[1, 0].plot(temperature, rat_L[3], marker='o', markersize=4, linestyle='dashed', color='dimgrey')

axs[1, 0].set_title('[RABBIT]')
axs[1, 0].set_xticks([0.6, 0.8, 1.0, 1.2])


# [RAT] conditioning tag

# [HEAVY] conditioning tag
axs[1, 1].plot(temperature, human_H[4], marker='o', markersize=4, color='dodgerblue')
axs[1, 1].plot(temperature, mouse_H[4], marker='o', markersize=4, color='darkorange')
axs[1, 1].plot(temperature, alpaca_H[4], marker='o', markersize=4, color='limegreen')
axs[1, 1].plot(temperature, rabbit_H[4], marker='o', markersize=4, color='orangered')
axs[1, 1].plot(temperature, pig_H[4], marker='o', markersize=4, color='mediumpurple')
axs[1, 1].plot(temperature, rhesus_H[4], marker='o', markersize=4, color='saddlebrown')
axs[1, 1].plot(temperature, cow_H[4], marker='o', markersize=4, color='hotpink')
axs[1, 1].plot(temperature, rat_H[4], marker='o', markersize=4, color='dimgrey')

# [LIGHT] conditioning tag
axs[1, 1].plot(temperature, human_L[4], marker='o', markersize=4, linestyle='dashed', color='dodgerblue')
axs[1, 1].plot(temperature, mouse_L[4], marker='o', markersize=4, linestyle='dashed', color='darkorange')
axs[1, 1].plot(temperature, rabbit_L[4], marker='o', markersize=4, linestyle='dashed', color='orangered')
axs[1, 1].plot(temperature, pig_L[4], marker='o', markersize=4, linestyle='dashed', color='mediumpurple')
axs[1, 1].plot(temperature, rhesus_L[4], marker='o', markersize=4, linestyle='dashed', color='saddlebrown')
axs[1, 1].plot(temperature, cow_L[4], marker='o', markersize=4, linestyle='dashed', color='hotpink')
axs[1, 1].plot(temperature, rat_L[4], marker='o', markersize=4, linestyle='dashed', color='dimgrey')

axs[1, 1].set_title('[RAT]')
axs[1, 1].set_xticks([0.6, 0.8, 1.0, 1.2])


# [RHESUS] conditioning tag

# [HEAVY] conditioning tag
axs[1, 2].plot(temperature, human_H[5], marker='o', markersize=4, color='dodgerblue')
axs[1, 2].plot(temperature, mouse_H[5], marker='o', markersize=4, color='darkorange')
axs[1, 2].plot(temperature, alpaca_H[5], marker='o', markersize=4, color='limegreen')
axs[1, 2].plot(temperature, rabbit_H[5], marker='o', markersize=4, color='orangered')
axs[1, 2].plot(temperature, pig_H[5], marker='o', markersize=4, color='mediumpurple')
axs[1, 2].plot(temperature, rhesus_H[5], marker='o', markersize=4, color='saddlebrown')
axs[1, 2].plot(temperature, cow_H[5], marker='o', markersize=4, color='hotpink')
axs[1, 2].plot(temperature, rat_H[5], marker='o', markersize=4, color='dimgrey')

# [LIGHT] conditioning tag
axs[1, 2].plot(temperature, human_L[5], marker='o', markersize=4, linestyle='dashed', color='dodgerblue')
axs[1, 2].plot(temperature, mouse_L[5], marker='o', markersize=4, linestyle='dashed', color='darkorange')
axs[1, 2].plot(temperature, rabbit_L[5], marker='o', markersize=4, linestyle='dashed', color='orangered')
axs[1, 2].plot(temperature, pig_L[5], marker='o', markersize=4, linestyle='dashed', color='mediumpurple')
axs[1, 2].plot(temperature, rhesus_L[5], marker='o', markersize=4, linestyle='dashed', color='saddlebrown')
axs[1, 2].plot(temperature, cow_L[5], marker='o', markersize=4, linestyle='dashed', color='hotpink')
axs[1, 2].plot(temperature, rat_L[5], marker='o', markersize=4, linestyle='dashed', color='dimgrey')

axs[1, 2].set_title('[RHESUS]')
axs[1, 2].set_xticks([0.6, 0.8, 1.0, 1.2])


for ax in axs.flat:
    ax.set(xlabel='Temperature', ylabel='Percent')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
    
legend1 = axs[0, 0].legend(loc='center left', bbox_to_anchor=(3.5, -0.35))
legend2 = axs[0, 1].legend(loc='center left', bbox_to_anchor=(2.3, 0.5))

plt.savefig('iglm_reproduction.png', bbox_inches='tight')

# %% [markdown]
# ## Checking for partial match: chain ONLY

# %%
keys = []
for key in elements_count.keys():
    if type(key) != float:
        keys.append(key)
    else:
        continue
                
for k in range(len(keys)):
    keys[k] = keys[k][-1]
    
keys
# Out:
# ['H', 'H', 'H', 'H', 'H']

# %%
# Initialize different species types

# human = [ [1 2 3], [1 2 3], [1 2 3] ]

human = []
mouse = []
camel = []
rabbit = []
rhesus = []
rat = []


# Organize by tokens
chain_tokens = ['H', 'L', 'K']
species_tokens = ["[CAMEL]", "[HUMAN]", "[MOUSE]", "[RABBIT]", "[RAT]", "[RHESUS]"]
k = 0

for j in chain_tokens:
    for i in species_tokens:
        heavy = np.zeros(6)
        lamb = np.zeros(6)
        kap = np.zeros(6)
        
        count_H = 0
        count_L = 0
        count_K = 0
        total = 0
        
        for t in temperature:
            keys = []
            if j == 'H':
                start = names.index(f"{i}0:{t}:{j}")
                end = names.index(f"{i}1999:{t}:{j}")
                
                # getting the elements frequencies using Counter class
                elements_count = collections.Counter(label[start:end])
                vals = np.fromiter(elements_count.values(), dtype=int)

                for key in elements_count.keys():
                    if type(key) != float:
                        keys.append(key)
                    else:
                        continue
                
                for k in range(len(keys)):
                    keys[k] = keys[k][-1]
                
                for s in set(keys):
                    indices = [i for i, x in enumerate(keys) if x == s]
                    if s == 'H':
                        count_H += sum(vals[indices])
                    elif s == 'L':
                        count_L += sum(vals[indices])
                    else:
                        count_K += sum(vals[indices])
                
                total += sum(vals)
                
                
            else:
                if i == "[CAMEL]":
                    continue
                else:
                    start = names.index(f"{i}0:{t}:{j}")
                    end = names.index(f"{i}999:{t}:K")

                    # getting the elements frequencies using Counter class
                    elements_count = collections.Counter(label[start:end])
                    vals = np.fromiter(elements_count.values(), dtype=int)
                    
                    for key in elements_count.keys():
                        if type(key) != float:
                            keys.append(key)
                        else:
                            continue
                    for k in range(len(keys)):
                        keys[k] = keys[k][-1]

                    for s in set(keys):
                        indices = [i for i, x in enumerate(keys) if x == s]
                        if s == 'H':
                            count_H += sum(vals[indices])
                        elif s == 'L':
                            count_L += sum(vals[indices])
                        else:
                            count_K += sum(vals[indices])
                
                    total += sum(vals)
        
        if j == 'H':
            if i == '[HUMAN]':
                human.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])
            elif i == '[MOUSE]':
                mouse.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])
            elif i == '[CAMEL]':
                camel.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])
            elif i == '[RABBIT]':
                rabbit.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])
            elif i == '[RHESUS]':
                rhesus.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])
            elif i == '[RAT]':
                rat.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])
        else:
            if i == '[HUMAN]':
                human.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])
            elif i == '[MOUSE]':
                mouse.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])
            elif i == '[CAMEL]':
                camel.append([0, 0, 0])
            elif i == '[RABBIT]':
                rabbit.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])
            elif i == '[RHESUS]':
                rhesus.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])
            elif i == '[RAT]':
                rat.append([(count_H/total)*100, (count_L/total)*100, (count_K/total)*100])

# %%
human
# Out:
# [[99.8249124562281, 0.0, 0.0],
#  [0.0, 50.0, 49.88744372186093],
#  [0.0, 0.0, 100.0]]

# %%
# set width of bar
barWidth = 0.25
fig = plt.subplots()
 
# set height of bar
Heavy = [camel[2][0], human[2][0], mouse[2][0], rabbit[2][0], rat[2][0], rhesus[2][0]]
Lambda = [camel[2][1], human[2][1], mouse[2][1], rabbit[2][1], rat[2][1], rhesus[2][1]]
Kappa = [camel[2][2], human[2][2], mouse[2][2], rabbit[2][2], rat[2][2], rhesus[2][2]]
 
# Set position of bar on X axis
br1 = np.arange(len(Heavy))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, Heavy, color ='darkslategrey', width = barWidth, label ='Heavy')
plt.bar(br2, Lambda, color ='teal', width = barWidth, label ='Lambda')
plt.bar(br3, Kappa, color ='limegreen', width = barWidth, label ='Kappa')
 
# Adding Xticks
plt.ylabel('Percent', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(Heavy))],
        ["[CAMEL]", "[HUMAN]", "[MOUSE]", "[RABBIT]", "[RAT]", "[RHESUS]"])
plt.title('[LIGHT] (Kappa)')
 
plt.legend()
plt.show()

# %% [markdown]
# ## Checking for complete match: species AND chain type

# %%
# Count the number of matching labels

no_count = []  # for sequences not numbered by ANARCI
count_data = np.zeros(len(flattened_seqs))
for i in range(len(anarci_sequences)):    
    if numbering[i] is None:
        no_count.append(anarci_sequences[i][0])
        count_data[i] = np.nan
    else:
        for j in range(len(numbering[i])):
            label = alignment_details[i][j].get("id")
            if (label[0:len(label)-2] in names[i].lower()) & (label[-1] == names[i][-1]):
                count_data[i] = 1
            else:
                count_data[i] = 0

# %%
## EXAMPLE: indexing the for count_data

# t = 0.6
# i = '[RABBIT]'
# j = 'H'

# if j == 'H':
#     start = names.index(f"{i}0:{t}:{j}")
#     end = names.index(f"{i}1999:{t}:{j}")
# else:
#     start = names.index(f"{i}0:{t}:{j}")
#     end = names.index(f"{i}999:{t}:{j}")
    
# print(start, end)
# np.nanmean(count_data[start:end])

# %%
chain_tokens = ['H', 'L', 'K']
species_tokens = ["[HUMAN]", "[MOUSE]", "[RABBIT]", "[RAT]", "[RHESUS]", "[CAMEL]"]
k = 0

perc_correct = np.zeros(len(generated_seqs))
perc_nocount = []

for t in temperature:
    for i in species_tokens:
        for j in chain_types:
            if j == 'H':
                start = names.index(f"{i}0:{t}:{j}")
                end = names.index(f"{i}1999:{t}:{j}")
                perc_correct[k] = np.nanmean(count_data[start:end])
                k += 1
            else:
                if i == "[CAMEL]":
                    continue
                else:
                    start = names.index(f"{i}0:{t}:{j}")
                    end = names.index(f"{i}999:{t}:{j}")
                    perc_correct[k] = np.nanmean(count_data[start:end])
                    k += 1
            
print(perc_correct)
# Out:
# [0.02451226 0.2972973  0.84784785 0.99749875 0.87487487 0.0970971
#  1.         0.         0.         0.         0.002002   0.
#  0.65332666 0.95895896 0.26526527 0.         0.05852926 0.31031031
#  0.80980981 0.99149575 0.87387387 0.08808809 1.         0.
#  0.         0.         0.         0.         0.67333667 0.95095095
#  0.26426426 0.         0.09154577 0.32532533 0.82282282 0.98549275
#  0.86686687 0.12712713 1.         0.         0.         0.
#  0.00201207 0.         0.68934467 0.95795796 0.28728729 0.
#  0.13383459 0.27983952 0.77577578 0.95597799 0.84854564 0.15245737
#  0.99949975 0.         0.00319489 0.         0.00320856 0.01132853
#  0.60871743 0.94388778 0.33366733 0.        ]

# %% [markdown]
# ## Code from ANARCI GitHub

# %%
# Each has the same number of elements as the number of sequences submitted
assert len(numbering) == len(alignment_details) == len(hit_tables) == len( anarci_sequences )

# Iterate over the sequences
for i in range(len(anarci_sequences)):    
    if numbering[i] is None:
        print('ANARCI did not number', anarci_sequences[i][0])
    else:
        print('ANARCI numbered', anarci_sequences[i][0])
        print('It identified %d domain(s)'%len(numbering[i]))
        
        # Iterate over the domains
        for j in range(len(numbering[i])):
            domain_numbering, start_index, end_index = numbering[i][j]
            # print('This is the IMGT numbering for the %d\'th domain:'%j, domain_numbering)
            # print('This is the bit of the sequence it corresponds to:', anarci_sequences[i][1][start_index:end_index+1])
            # print('These are the details of the alignment:')
            for (key,value) in alignment_details[i][j].items():
                print(key, ':', value)
            print('This is the summary of the hits that HMMER found')
            for line in hit_tables[i]:
                print(line)      
    print('\n','_'*40)
# Out:
# ANARCI numbered [HUMAN]0:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.9e-64
# bitscore : 205.5
# bias : 3.8
# query_start : 0
# query_end : 126
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]0:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.9e-64, 205.5, 3.8, 0, 126]
# ['human_H', '', 1.9e-60, 193.8, 2.1, 0, 126]
# ['rhesus_H', '', 1.4e-59, 191.0, 3.0, 0, 126]
# ['pig_H', '', 5.4e-58, 186.0, 3.9, 0, 126]
# ['mouse_H', '', 6.4e-56, 179.0, 1.5, 0, 126]
# ['rabbit_H', '', 4.1e-49, 157.1, 0.8, 2, 126]
# ['cow_H', '', 2.3e-37, 118.9, 1.3, 1, 126]
#
#  ________________________________________
# ANARCI numbered [HUMAN]1:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2.2e-63
# bitscore : 203.4
# bias : 2.1
# query_start : 0
# query_end : 119
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]1:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2.2e-63, 203.4, 2.1, 0, 119]
# ['human_H', '', 1.2e-58, 187.9, 1.1, 0, 119]
# ['rhesus_H', '', 2.1e-58, 187.1, 0.6, 0, 119]
# ['pig_H', '', 5.6e-57, 182.7, 2.6, 0, 119]
# ['mouse_H', '', 5.5e-55, 175.9, 0.2, 0, 119]
# ['rabbit_H', '', 1.4e-46, 148.9, 0.9, 2, 119]
# ['cow_H', '', 3.3e-35, 111.9, 0.8, 1, 119]
#
#  ________________________________________
# ANARCI numbered [HUMAN]2:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 3.4e-64
# bitscore : 206.0
# bias : 3.5
# query_start : 0
# query_end : 123
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]2:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 3.4e-64, 206.0, 3.5, 0, 123]
# ['human_H', '', 1.6e-60, 194.0, 1.7, 0, 123]
# ['rhesus_H', '', 4e-60, 192.7, 1.4, 0, 123]
# ['pig_H', '', 1.1e-58, 188.3, 3.5, 0, 123]
# ['mouse_H', '', 2.5e-56, 180.3, 1.4, 0, 123]
# ['rabbit_H', '', 7e-50, 159.6, 0.5, 2, 123]
# ['cow_H', '', 6e-37, 117.5, 0.9, 1, 123]
#
#  ________________________________________
# ANARCI numbered [HUMAN]3:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 6.3e-63
# bitscore : 201.9
# bias : 2.6
# query_start : 0
# query_end : 125
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]3:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 6.3e-63, 201.9, 2.6, 0, 125]
# ['human_H', '', 1.1e-59, 191.3, 1.3, 0, 125]
# ['rhesus_H', '', 8.6e-59, 188.4, 1.0, 0, 125]
# ['pig_H', '', 9.3e-59, 188.4, 2.4, 0, 125]
# ['mouse_H', '', 1.7e-55, 177.6, 1.0, 0, 125]
# ['rabbit_H', '', 6.3e-49, 156.5, 0.4, 2, 125]
# ['cow_H', '', 7.4e-37, 117.2, 0.4, 1, 125]
#
#  ________________________________________
# ANARCI numbered [HUMAN]4:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 7.1e-65
# bitscore : 208.2
# bias : 2.5
# query_start : 0
# query_end : 121
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]4:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 7.1e-65, 208.2, 2.5, 0, 121]
# ['human_H', '', 2.7e-61, 196.5, 1.8, 0, 121]
# ['rhesus_H', '', 9.2e-61, 194.7, 1.4, 0, 121]
# ['pig_H', '', 2.1e-59, 190.5, 2.8, 0, 121]
# ['mouse_H', '', 3.5e-56, 179.8, 0.8, 0, 121]
# ['rabbit_H', '', 6e-51, 163.0, 1.1, 2, 121]
# ['cow_H', '', 3.3e-38, 121.6, 1.8, 1, 121]
#
#  ________________________________________
# ANARCI numbered [HUMAN]5:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.3e-67
# bitscore : 217.0
# bias : 3.9
# query_start : 0
# query_end : 124
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]5:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.3e-67, 217.0, 3.9, 0, 124]
# ['pig_H', '', 2.9e-62, 199.8, 4.5, 0, 124]
# ['human_H', '', 3.1e-61, 196.3, 1.9, 0, 124]
# ['rhesus_H', '', 1.5e-60, 194.1, 1.4, 0, 124]
# ['mouse_H', '', 8.5e-57, 181.8, 1.1, 0, 124]
# ['rabbit_H', '', 2e-52, 167.8, 1.2, 2, 124]
# ['cow_H', '', 1.7e-40, 129.0, 1.9, 1, 124]
#
#  ________________________________________
# ANARCI numbered [HUMAN]6:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 3.1e-61
# bitscore : 196.5
# bias : 6.9
# query_start : 0
# query_end : 128
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]6:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 3.1e-61, 196.5, 6.9, 0, 128]
# ['human_H', '', 1.9e-58, 187.3, 4.0, 0, 128]
# ['pig_H', '', 2.2e-58, 187.3, 6.0, 0, 128]
# ['rhesus_H', '', 2.5e-57, 183.6, 5.2, 0, 128]
# ['mouse_H', '', 9.5e-54, 171.9, 4.7, 0, 128]
# ['rabbit_H', '', 2.2e-49, 157.9, 1.0, 2, 128]
# ['cow_H', '', 3.9e-37, 118.2, 2.2, 1, 128]
#
#  ________________________________________
# ANARCI numbered [HUMAN]7:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2.2e-63
# bitscore : 203.4
# bias : 8.9
# query_start : 0
# query_end : 131
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]7:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2.2e-63, 203.4, 8.9, 0, 131]
# ['pig_H', '', 2.1e-59, 190.5, 8.1, 0, 131]
# ['human_H', '', 2.8e-57, 183.5, 6.1, 0, 131]
# ['rhesus_H', '', 2.3e-53, 170.8, 0.2, 0, 105]
# ['mouse_H', '', 5.8e-53, 169.4, 5.4, 0, 131]
# ['rabbit_H', '', 4.6e-49, 156.9, 3.1, 2, 131]
# ['cow_H', '', 1.5e-37, 119.5, 5.6, 1, 131]
#
#  ________________________________________
# ANARCI numbered [HUMAN]8:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 5.5e-63
# bitscore : 202.1
# bias : 3.5
# query_start : 0
# query_end : 123
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]8:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 5.5e-63, 202.1, 3.5, 0, 123]
# ['human_H', '', 3.4e-61, 196.2, 1.7, 0, 123]
# ['rhesus_H', '', 1.1e-60, 194.5, 1.3, 0, 123]
# ['pig_H', '', 7.7e-60, 191.9, 4.0, 0, 123]
# ['mouse_H', '', 1.1e-55, 178.3, 1.0, 0, 123]
# ['rabbit_H', '', 1.9e-51, 164.7, 0.9, 2, 123]
# ['cow_H', '', 8.6e-38, 120.3, 1.7, 1, 123]
#
#  ________________________________________
# ANARCI numbered [HUMAN]9:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.5e-65
# bitscore : 208.9
# bias : 1.1
# query_start : 0
# query_end : 122
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]9:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.5e-65, 208.9, 1.1, 0, 122]
# ['human_H', '', 3.7e-61, 196.0, 0.5, 0, 122]
# ['rhesus_H', '', 8.3e-61, 194.9, 0.4, 0, 122]
# ['pig_H', '', 2.3e-60, 193.6, 1.2, 0, 122]
# ['mouse_H', '', 7.4e-57, 182.0, 0.1, 0, 122]
# ['rabbit_H', '', 8.1e-51, 162.6, 0.2, 2, 122]
# ['cow_H', '', 1.8e-37, 119.2, 0.5, 1, 122]
#
#  ________________________________________
# ANARCI numbered [HUMAN]10:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 7.4e-69
# bitscore : 221.1
# bias : 2.5
# query_start : 0
# query_end : 123
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]10:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 7.4e-69, 221.1, 2.5, 0, 123]
# ['pig_H', '', 1.1e-63, 204.3, 3.1, 0, 123]
# ['human_H', '', 2.4e-62, 199.9, 0.8, 0, 123]
# ['rhesus_H', '', 1.1e-61, 197.7, 0.6, 0, 123]
# ['mouse_H', '', 1.1e-57, 184.6, 0.2, 0, 123]
# ['rabbit_H', '', 5e-53, 169.7, 0.8, 2, 123]
# ['cow_H', '', 6.5e-41, 130.3, 1.4, 1, 123]
#
#  ________________________________________
# ANARCI numbered [HUMAN]11:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.8e-61
# bitscore : 197.2
# bias : 4.4
# query_start : 0
# query_end : 126
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]11:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.8e-61, 197.2, 4.4, 0, 126]
# ['human_H', '', 1.7e-59, 190.7, 2.6, 0, 126]
# ['pig_H', '', 4.8e-59, 189.4, 4.1, 0, 126]
# ['rhesus_H', '', 1.1e-58, 188.0, 2.0, 0, 126]
# ['mouse_H', '', 2.8e-55, 176.9, 1.8, 0, 126]
# ['rabbit_H', '', 3.2e-49, 157.4, 1.5, 2, 126]
# ['cow_H', '', 2.3e-37, 118.9, 2.5, 1, 126]
#
#  ________________________________________
# ANARCI numbered [HUMAN]12:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 5e-62
# bitscore : 199.0
# bias : 4.8
# query_start : 0
# query_end : 123
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]12:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 5e-62, 199.0, 4.8, 0, 123]
# ['human_H', '', 6.2e-60, 192.1, 2.8, 0, 123]
# ['pig_H', '', 1e-59, 191.6, 4.5, 0, 123]
# ['rhesus_H', '', 5e-59, 189.1, 2.1, 0, 123]
# ['mouse_H', '', 2.5e-55, 177.0, 2.2, 0, 123]
# ['rabbit_H', '', 6.4e-50, 159.7, 1.4, 2, 123]
# ['cow_H', '', 3.5e-38, 121.5, 2.2, 1, 123]
#
#  ________________________________________
# ANARCI numbered [HUMAN]13:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.3e-65
# bitscore : 208.9
# bias : 3.5
# query_start : 0
# query_end : 120
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]13:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.3e-65, 208.9, 3.5, 0, 120]
# ['human_H', '', 9.9e-61, 194.7, 1.9, 0, 120]
# ['rhesus_H', '', 7.6e-60, 191.8, 1.3, 0, 120]
# ['pig_H', '', 2.4e-59, 190.3, 3.8, 0, 120]
# ['mouse_H', '', 3.2e-56, 179.9, 0.4, 0, 120]
# ['rabbit_H', '', 2.1e-49, 158.0, 1.7, 2, 120]
# ['cow_H', '', 1.6e-37, 119.4, 2.3, 1, 120]
#
#  ________________________________________
# ANARCI numbered [HUMAN]14:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 7.8e-63
# bitscore : 201.6
# bias : 1.7
# query_start : 0
# query_end : 127
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]14:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 7.8e-63, 201.6, 1.7, 0, 127]
# ['human_H', '', 1.4e-59, 190.9, 0.8, 0, 127]
# ['rhesus_H', '', 1.8e-58, 187.3, 1.9, 0, 127]
# ['pig_H', '', 2.2e-58, 187.2, 1.9, 0, 127]
# ['mouse_H', '', 1.1e-55, 178.2, 0.5, 0, 127]
# ['rabbit_H', '', 1.7e-48, 155.1, 0.3, 2, 127]
# ['cow_H', '', 2.2e-36, 115.7, 0.3, 1, 127]
#
#  ________________________________________
# ANARCI numbered [HUMAN]15:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.7e-66
# bitscore : 212.0
# bias : 4.9
# query_start : 0
# query_end : 126
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]15:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.7e-66, 212.0, 4.9, 0, 126]
# ['pig_H', '', 8.3e-62, 198.3, 4.9, 0, 126]
# ['human_H', '', 7e-60, 191.9, 2.5, 0, 126]
# ['rhesus_H', '', 4.9e-59, 189.2, 1.7, 0, 126]
# ['mouse_H', '', 1.4e-55, 177.9, 1.3, 0, 126]
# ['rabbit_H', '', 6.8e-51, 162.8, 1.8, 2, 126]
# ['cow_H', '', 9.2e-40, 126.6, 2.0, 1, 126]
#
#  ________________________________________
# ANARCI numbered [HUMAN]16:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.1e-67
# bitscore : 217.4
# bias : 3.8
# query_start : 0
# query_end : 126
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]16:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.1e-67, 217.4, 3.8, 0, 126]
# ['pig_H', '', 2.8e-62, 199.9, 5.2, 0, 126]
# ['human_H', '', 1.6e-61, 197.2, 1.1, 0, 126]
# ['rhesus_H', '', 8.8e-61, 194.8, 0.7, 0, 126]
# ['mouse_H', '', 6.8e-57, 182.1, 0.2, 0, 126]
# ['rabbit_H', '', 3.4e-52, 167.0, 1.1, 2, 126]
# ['cow_H', '', 4.5e-40, 127.6, 1.7, 1, 126]
#
#  ________________________________________
# ANARCI numbered [HUMAN]17:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.6e-60
# bitscore : 194.2
# bias : 5.8
# query_start : 0
# query_end : 131
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]17:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.6e-60, 194.2, 5.8, 0, 131]
# ['human_H', '', 1.9e-57, 184.1, 4.2, 0, 131]
# ['pig_H', '', 1.3e-56, 181.5, 4.3, 0, 131]
# ['rhesus_H', '', 2.5e-56, 180.4, 4.9, 0, 131]
# ['mouse_H', '', 2.6e-53, 170.5, 4.6, 0, 131]
# ['rabbit_H', '', 4.4e-47, 150.5, 1.4, 2, 131]
# ['cow_H', '', 6.1e-35, 111.0, 1.6, 1, 131]
#
#  ________________________________________
# ANARCI numbered [HUMAN]18:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.4e-64
# bitscore : 207.3
# bias : 3.1
# query_start : 0
# query_end : 119
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]18:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.4e-64, 207.3, 3.1, 0, 119]
# ['human_H', '', 9.2e-62, 198.0, 1.6, 0, 119]
# ['rhesus_H', '', 1.1e-61, 197.7, 1.2, 0, 119]
# ['pig_H', '', 7.1e-61, 195.3, 3.6, 0, 119]
# ['mouse_H', '', 1e-57, 184.8, 0.9, 0, 119]
# ['rabbit_H', '', 4.6e-52, 166.6, 0.8, 2, 119]
# ['cow_H', '', 7.6e-39, 123.7, 1.4, 1, 119]
#
#  ________________________________________
# ANARCI numbered [HUMAN]19:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 6.2e-65
# bitscore : 208.4
# bias : 1.0
# query_start : 0
# query_end : 119
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]19:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 6.2e-65, 208.4, 1.0, 0, 119]
# ['human_H', '', 9.1e-62, 198.0, 0.4, 0, 119]
# ['rhesus_H', '', 2.3e-61, 196.7, 0.4, 0, 119]
# ['pig_H', '', 4.5e-60, 192.7, 1.3, 0, 119]
# ['mouse_H', '', 1.1e-56, 181.5, 0.2, 0, 119]
# ['rabbit_H', '', 7.5e-52, 165.9, 0.2, 2, 119]
# ['cow_H', '', 1.7e-38, 122.6, 0.3, 1, 119]
#
#  ________________________________________
# ANARCI numbered [HUMAN]20:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.1e-57
# bitscore : 185.0
# bias : 10.1
# query_start : 0
# query_end : 134
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]20:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.1e-57, 185.0, 10.1, 0, 134]
# ['human_H', '', 1e-55, 178.4, 7.5, 0, 134]
# ['pig_H', '', 1.1e-55, 178.5, 8.5, 0, 134]
# ['rhesus_H', '', 3.2e-53, 170.4, 0.3, 0, 99]
# ['mouse_H', '', 4.4e-51, 163.3, 7.4, 0, 134]
# ['rabbit_H', '', 7.5e-47, 149.8, 3.5, 2, 134]
# ['cow_H', '', 2.6e-33, 105.8, 6.1, 1, 134]
#
#  ________________________________________
# ANARCI numbered [HUMAN]21:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.6e-63
# bitscore : 202.4
# bias : 3.4
# query_start : 0
# query_end : 124
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]21:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.6e-63, 202.4, 3.4, 0, 124]
# ['human_H', '', 9.7e-60, 191.5, 2.1, 0, 124]
# ['pig_H', '', 5.4e-59, 189.2, 2.9, 0, 124]
# ['rhesus_H', '', 5.7e-59, 188.9, 1.5, 0, 124]
# ['mouse_H', '', 9.4e-56, 178.4, 1.4, 0, 124]
# ['rabbit_H', '', 4.3e-49, 157.0, 0.9, 2, 124]
# ['cow_H', '', 2.4e-37, 118.8, 0.8, 1, 124]
#
#  ________________________________________
# ANARCI numbered [HUMAN]22:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 3e-65
# bitscore : 209.4
# bias : 1.7
# query_start : 0
# query_end : 121
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]22:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 3e-65, 209.4, 1.7, 0, 121]
# ['human_H', '', 6.6e-62, 198.5, 0.8, 0, 121]
# ['rhesus_H', '', 1.8e-61, 197.1, 0.6, 0, 121]
# ['pig_H', '', 7.6e-60, 192.0, 2.0, 0, 121]
# ['mouse_H', '', 7.8e-58, 185.2, 0.4, 0, 121]
# ['rabbit_H', '', 5.3e-51, 163.2, 0.2, 2, 121]
# ['cow_H', '', 5.3e-38, 120.9, 0.4, 1, 121]
#
#  ________________________________________
# ANARCI numbered [HUMAN]23:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 6.2e-62
# bitscore : 198.7
# bias : 6.2
# query_start : 0
# query_end : 124
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]23:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 6.2e-62, 198.7, 6.2, 0, 124]
# ['human_H', '', 8.8e-60, 191.6, 4.2, 0, 124]
# ['pig_H', '', 1.6e-59, 190.9, 5.9, 0, 124]
# ['rhesus_H', '', 2.6e-59, 190.0, 3.3, 0, 124]
# ['mouse_H', '', 1.8e-55, 177.5, 3.2, 0, 124]
# ['rabbit_H', '', 3e-50, 160.8, 2.6, 2, 124]
# ['cow_H', '', 3.3e-37, 118.4, 3.6, 1, 124]
#
#  ________________________________________
# ANARCI numbered [HUMAN]24:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.2e-63
# bitscore : 204.2
# bias : 4.4
# query_start : 0
# query_end : 121
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]24:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.2e-63, 204.2, 4.4, 0, 121]
# ['human_H', '', 9.8e-61, 194.7, 2.3, 0, 121]
# ['rhesus_H', '', 3.2e-60, 193.0, 1.8, 0, 121]
# ['pig_H', '', 1.1e-59, 191.5, 4.6, 0, 121]
# ['mouse_H', '', 3.6e-56, 179.8, 1.5, 0, 121]
# ['rabbit_H', '', 1.3e-50, 162.0, 1.1, 2, 121]
# ['cow_H', '', 2.1e-38, 122.2, 2.5, 1, 121]
#
#  ________________________________________
# ANARCI numbered [HUMAN]25:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 8e-62
# bitscore : 198.4
# bias : 5.2
# query_start : 0
# query_end : 124
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]25:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 8e-62, 198.4, 5.2, 0, 124]
# ['human_H', '', 5.7e-60, 192.2, 3.1, 0, 124]
# ['pig_H', '', 3.3e-59, 189.9, 5.4, 0, 124]
# ['rhesus_H', '', 4.1e-59, 189.4, 2.5, 0, 124]
# ['mouse_H', '', 8.8e-56, 178.5, 2.1, 0, 124]
# ['rabbit_H', '', 8.4e-50, 159.3, 1.8, 2, 124]
# ['cow_H', '', 7.3e-38, 120.5, 2.8, 1, 124]
#
#  ________________________________________
# ANARCI numbered [HUMAN]26:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.7e-58
# bitscore : 187.6
# bias : 9.7
# query_start : 0
# query_end : 130
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]26:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.7e-58, 187.6, 9.7, 0, 130]
# ['human_H', '', 1.1e-56, 181.7, 7.6, 0, 130]
# ['pig_H', '', 3.8e-56, 180.0, 7.9, 0, 130]
# ['rhesus_H', '', 1.2e-55, 178.2, 7.9, 0, 130]
# ['mouse_H', '', 1.7e-52, 167.9, 7.6, 0, 130]
# ['rabbit_H', '', 9.6e-49, 155.9, 4.0, 2, 130]
# ['cow_H', '', 4.6e-35, 111.4, 5.8, 1, 130]
#
#  ________________________________________
# ANARCI numbered [HUMAN]27:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.4e-65
# bitscore : 208.9
# bias : 2.1
# query_start : 0
# query_end : 120
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]27:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.4e-65, 208.9, 2.1, 0, 120]
# ['human_H', '', 3.7e-62, 199.3, 0.8, 0, 120]
# ['pig_H', '', 1.7e-61, 197.3, 2.3, 0, 120]
# ['rhesus_H', '', 2.2e-61, 196.7, 0.7, 0, 120]
# ['mouse_H', '', 3.8e-58, 186.2, 0.4, 0, 120]
# ['rabbit_H', '', 2.2e-52, 167.6, 0.5, 2, 120]
# ['cow_H', '', 6.1e-39, 124.0, 1.4, 1, 120]
#
#  ________________________________________
# ANARCI numbered [HUMAN]28:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 9.4e-65
# bitscore : 207.8
# bias : 3.4
# query_start : 0
# query_end : 116
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]28:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 9.4e-65, 207.8, 3.4, 0, 116]
# ['rhesus_H', '', 9.9e-61, 194.6, 1.3, 0, 116]
# ['pig_H', '', 1.1e-60, 194.7, 3.9, 0, 116]
# ['human_H', '', 2.5e-60, 193.4, 1.9, 0, 116]
# ['mouse_H', '', 8.4e-56, 178.6, 0.6, 0, 116]
# ['rabbit_H', '', 9.5e-53, 168.8, 1.1, 2, 116]
# ['cow_H', '', 8.1e-40, 126.8, 2.2, 1, 116]
#
#  ________________________________________
# ANARCI numbered [HUMAN]29:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 9.8e-64
# bitscore : 204.5
# bias : 3.4
# query_start : 0
# query_end : 121
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]29:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 9.8e-64, 204.5, 3.4, 0, 121]
# ['pig_H', '', 8.7e-61, 195.0, 3.2, 0, 121]
# ['human_H', '', 2.7e-60, 193.2, 2.4, 0, 121]
# ['rhesus_H', '', 4.4e-60, 192.6, 1.7, 0, 121]
# ['mouse_H', '', 1.6e-56, 180.9, 1.3, 0, 121]
# ['rabbit_H', '', 6.1e-51, 163.0, 2.1, 2, 121]
# ['cow_H', '', 4.8e-38, 121.1, 2.8, 1, 121]
#
#  ________________________________________
# ANARCI numbered [HUMAN]30:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.3e-63
# bitscore : 204.1
# bias : 2.2
# query_start : 0
# query_end : 123
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]30:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.3e-63, 204.1, 2.2, 0, 123]
# ['human_H', '', 1.8e-60, 193.8, 1.2, 0, 123]
# ['rhesus_H', '', 5.9e-60, 192.1, 1.0, 0, 123]
# ['pig_H', '', 1.4e-58, 187.9, 2.4, 0, 123]
# ['mouse_H', '', 1.1e-55, 178.2, 0.7, 0, 123]
# ['rabbit_H', '', 9.7e-51, 162.3, 0.5, 2, 123]
# ['cow_H', '', 2.8e-37, 118.6, 0.7, 1, 123]
#
#  ________________________________________
# ANARCI numbered [HUMAN]31:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.8e-64
# bitscore : 206.9
# bias : 2.3
# query_start : 0
# query_end : 122
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]31:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.8e-64, 206.9, 2.3, 0, 122]
# ['human_H', '', 1.5e-60, 194.1, 1.0, 0, 122]
# ['rhesus_H', '', 1.7e-59, 190.7, 0.7, 0, 122]
# ['pig_H', '', 4.1e-57, 183.1, 2.8, 0, 122]
# ['mouse_H', '', 6.4e-56, 178.9, 0.5, 0, 122]
# ['rabbit_H', '', 8e-49, 156.1, 0.6, 2, 122]
# ['cow_H', '', 2e-39, 125.5, 0.6, 1, 122]
#
#  ________________________________________
# ANARCI numbered [HUMAN]32:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2.4e-62
# bitscore : 200.1
# bias : 4.3
# query_start : 0
# query_end : 128
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]32:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2.4e-62, 200.1, 4.3, 0, 128]
# ['human_H', '', 1.2e-59, 191.2, 1.3, 0, 128]
# ['rhesus_H', '', 3.3e-58, 186.5, 2.9, 0, 128]
# ['pig_H', '', 4.1e-58, 186.4, 3.2, 0, 128]
# ['mouse_H', '', 3e-54, 173.6, 2.6, 0, 128]
# ['rabbit_H', '', 1.9e-49, 158.1, 0.3, 2, 128]
# ['cow_H', '', 2.9e-36, 115.3, 0.3, 1, 128]
#
#  ________________________________________
# ANARCI numbered [HUMAN]33:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 3.9e-69
# bitscore : 222.0
# bias : 4.5
# query_start : 0
# query_end : 120
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]33:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 3.9e-69, 222.0, 4.5, 0, 120]
# ['pig_H', '', 9.4e-64, 204.6, 5.1, 0, 120]
# ['human_H', '', 1.2e-62, 200.9, 1.7, 0, 120]
# ['rhesus_H', '', 6.1e-62, 198.5, 1.1, 0, 120]
# ['mouse_H', '', 6.1e-58, 185.5, 0.7, 0, 120]
# ['rabbit_H', '', 7.7e-54, 172.4, 1.3, 2, 120]
# ['cow_H', '', 8.7e-42, 133.2, 2.0, 1, 120]
#
#  ________________________________________
# ANARCI numbered [HUMAN]34:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.1e-64
# bitscore : 207.6
# bias : 1.6
# query_start : 0
# query_end : 118
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]34:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.1e-64, 207.6, 1.6, 0, 118]
# ['rhesus_H', '', 2.5e-62, 199.8, 0.4, 0, 118]
# ['human_H', '', 1.8e-61, 197.1, 0.6, 0, 118]
# ['pig_H', '', 5.4e-61, 195.7, 2.3, 0, 118]
# ['mouse_H', '', 5.2e-56, 179.3, 0.2, 0, 118]
# ['rabbit_H', '', 7.8e-53, 169.1, 0.4, 2, 118]
# ['cow_H', '', 2.4e-39, 125.3, 0.6, 1, 118]
#
#  ________________________________________
# ANARCI numbered [HUMAN]35:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2.4e-65
# bitscore : 209.7
# bias : 2.6
# query_start : 0
# query_end : 119
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]35:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2.4e-65, 209.7, 2.6, 0, 119]
# ['human_H', '', 1.2e-61, 197.7, 1.2, 0, 119]
# ['rhesus_H', '', 1.7e-61, 197.1, 0.9, 0, 119]
# ['pig_H', '', 9.8e-60, 191.6, 2.9, 0, 119]
# ['mouse_H', '', 1.5e-57, 184.2, 0.7, 0, 119]
# ['rabbit_H', '', 7.6e-51, 162.7, 0.3, 2, 119]
# ['cow_H', '', 4.9e-38, 121.1, 0.6, 1, 119]
#
#  ________________________________________
# ANARCI numbered [HUMAN]36:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.5e-64
# bitscore : 205.6
# bias : 2.7
# query_start : 0
# query_end : 119
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]36:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.5e-64, 205.6, 2.7, 0, 119]
# ['human_H', '', 3.8e-62, 199.3, 1.1, 0, 119]
# ['rhesus_H', '', 1.1e-61, 197.7, 0.9, 0, 119]
# ['pig_H', '', 3.1e-61, 196.4, 3.1, 0, 119]
# ['mouse_H', '', 2.9e-56, 180.1, 0.4, 0, 119]
# ['rabbit_H', '', 6.2e-52, 166.2, 0.8, 2, 119]
# ['cow_H', '', 2.1e-39, 125.5, 2.2, 1, 119]
#
#  ________________________________________
# ANARCI numbered [HUMAN]37:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 7.1e-64
# bitscore : 205.0
# bias : 2.0
# query_start : 0
# query_end : 116
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]37:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 7.1e-64, 205.0, 2.0, 0, 116]
# ['rhesus_H', '', 8.3e-61, 194.9, 0.7, 0, 116]
# ['human_H', '', 3.2e-60, 193.0, 0.9, 0, 116]
# ['pig_H', '', 1.1e-58, 188.2, 2.3, 0, 116]
# ['mouse_H', '', 3.5e-56, 179.8, 0.4, 0, 116]
# ['rabbit_H', '', 1.5e-49, 158.5, 0.3, 2, 116]
# ['cow_H', '', 8.7e-37, 117.0, 0.5, 1, 116]
#
#  ________________________________________
# ANARCI numbered [HUMAN]38:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2e-61
# bitscore : 197.1
# bias : 4.6
# query_start : 0
# query_end : 125
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]38:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2e-61, 197.1, 4.6, 0, 125]
# ['human_H', '', 1.8e-59, 190.6, 2.1, 0, 125]
# ['pig_H', '', 5.6e-59, 189.2, 4.7, 0, 125]
# ['rhesus_H', '', 1.7e-58, 187.4, 1.6, 0, 125]
# ['mouse_H', '', 9e-55, 175.2, 1.4, 0, 125]
# ['rabbit_H', '', 2.2e-49, 158.0, 0.9, 2, 125]
# ['cow_H', '', 1.8e-37, 119.2, 2.2, 1, 125]
#
#  ________________________________________
# ANARCI numbered [HUMAN]39:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2.4e-63
# bitscore : 203.3
# bias : 3.5
# query_start : 0
# query_end : 124
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]39:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2.4e-63, 203.3, 3.5, 0, 124]
# ['human_H', '', 3e-60, 193.1, 1.7, 0, 124]
# ['pig_H', '', 3.2e-60, 193.2, 3.6, 0, 124]
# ['rhesus_H', '', 9.6e-60, 191.5, 1.2, 0, 124]
# ['mouse_H', '', 6.3e-56, 179.0, 0.8, 0, 124]
# ['rabbit_H', '', 2.2e-50, 161.2, 1.2, 2, 124]
# ['cow_H', '', 5.3e-38, 120.9, 1.4, 1, 124]
#
#  ________________________________________
# ANARCI numbered [HUMAN]40:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 5.8e-64
# bitscore : 205.3
# bias : 8.1
# query_start : 0
# query_end : 130
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]40:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 5.8e-64, 205.3, 8.1, 0, 130]
# ['pig_H', '', 1.1e-59, 191.5, 8.1, 0, 130]
# ['human_H', '', 7.6e-58, 185.3, 5.4, 0, 130]
# ['rhesus_H', '', 3.7e-56, 179.9, 7.2, 0, 130]
# ['mouse_H', '', 7.7e-53, 169.0, 6.5, 0, 130]
# ['rabbit_H', '', 1.5e-49, 158.5, 2.5, 2, 130]
# ['cow_H', '', 1e-37, 120.0, 5.2, 1, 130]
#
#  ________________________________________
# ANARCI numbered [HUMAN]41:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4e-63
# bitscore : 202.6
# bias : 9.8
# query_start : 0
# query_end : 130
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]41:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4e-63, 202.6, 9.8, 0, 130]
# ['pig_H', '', 1.6e-59, 190.9, 8.3, 0, 130]
# ['human_H', '', 1.2e-56, 181.5, 7.0, 0, 130]
# ['rhesus_H', '', 8.6e-56, 178.7, 6.4, 0, 130]
# ['mouse_H', '', 3.1e-52, 167.0, 5.3, 0, 130]
# ['rabbit_H', '', 1.1e-48, 155.8, 3.8, 2, 130]
# ['cow_H', '', 2.8e-37, 118.6, 6.1, 1, 130]
#
#  ________________________________________
# ANARCI numbered [HUMAN]42:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.1e-62
# bitscore : 201.1
# bias : 2.6
# query_start : 0
# query_end : 121
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]42:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.1e-62, 201.1, 2.6, 0, 121]
# ['pig_H', '', 3.5e-60, 193.0, 3.0, 0, 121]
# ['human_H', '', 9.3e-60, 191.5, 1.0, 0, 121]
# ['rhesus_H', '', 5.5e-59, 189.0, 0.8, 0, 121]
# ['mouse_H', '', 3.9e-54, 173.2, 0.3, 0, 121]
# ['rabbit_H', '', 2.2e-50, 161.2, 0.8, 2, 121]
# ['cow_H', '', 1.3e-37, 119.7, 2.3, 1, 121]
#
#  ________________________________________
# ANARCI numbered [HUMAN]43:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2.3e-64
# bitscore : 206.6
# bias : 3.9
# query_start : 0
# query_end : 120
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]43:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2.3e-64, 206.6, 3.9, 0, 120]
# ['human_H', '', 1.6e-60, 194.0, 2.1, 0, 120]
# ['rhesus_H', '', 1.3e-59, 191.0, 1.7, 0, 120]
# ['pig_H', '', 6.3e-59, 189.0, 4.0, 0, 120]
# ['mouse_H', '', 2.9e-56, 180.1, 1.3, 0, 120]
# ['rabbit_H', '', 7.4e-50, 159.5, 0.8, 2, 120]
# ['cow_H', '', 1.4e-36, 116.3, 1.2, 1, 120]
#
#  ________________________________________
# ANARCI numbered [HUMAN]44:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 6.1e-60
# bitscore : 192.3
# bias : 7.9
# query_start : 0
# query_end : 130
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]44:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 6.1e-60, 192.3, 7.9, 0, 130]
# ['human_H', '', 4.8e-58, 186.0, 5.4, 0, 130]
# ['rhesus_H', '', 3.1e-57, 183.4, 5.4, 0, 130]
# ['pig_H', '', 1.1e-56, 181.7, 7.2, 0, 130]
# ['mouse_H', '', 2.4e-53, 170.6, 5.4, 0, 130]
# ['rabbit_H', '', 9.2e-49, 155.9, 1.6, 2, 130]
# ['cow_H', '', 2.4e-35, 112.4, 5.2, 1, 130]
#
#  ________________________________________
# ANARCI numbered [HUMAN]45:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 6e-60
# bitscore : 192.3
# bias : 6.5
# query_start : 0
# query_end : 128
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]45:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 6e-60, 192.3, 6.5, 0, 128]
# ['pig_H', '', 3.7e-58, 186.5, 4.6, 0, 128]
# ['human_H', '', 7.1e-58, 185.4, 4.3, 0, 128]
# ['rhesus_H', '', 5.1e-56, 179.4, 6.6, 0, 128]
# ['mouse_H', '', 2e-52, 167.7, 6.0, 0, 128]
# ['rabbit_H', '', 2e-48, 154.9, 1.1, 2, 128]
# ['cow_H', '', 4.3e-37, 118.0, 1.8, 1, 128]
#
#  ________________________________________
# ANARCI numbered [HUMAN]46:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 6.4e-63
# bitscore : 201.9
# bias : 4.6
# query_start : 0
# query_end : 124
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]46:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 6.4e-63, 201.9, 4.6, 0, 124]
# ['human_H', '', 8.3e-60, 191.7, 3.3, 0, 124]
# ['rhesus_H', '', 3.6e-59, 189.6, 2.7, 0, 124]
# ['pig_H', '', 1.2e-58, 188.0, 4.3, 0, 124]
# ['mouse_H', '', 5.4e-56, 179.2, 2.6, 0, 124]
# ['rabbit_H', '', 3.6e-49, 157.3, 1.3, 2, 124]
# ['cow_H', '', 6.9e-37, 117.3, 1.8, 1, 124]
#
#  ________________________________________
# ANARCI numbered [HUMAN]47:0.6:H
# It identified 1 domain(s)
# id : human_H
# description :
# evalue : 4.9e-62
# bitscore : 198.9
# bias : 0.8
# query_start : 0
# query_end : 122
# species : human
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]47:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['human_H', '', 4.9e-62, 198.9, 0.8, 0, 122]
# ['rhesus_H', '', 4e-61, 195.9, 0.5, 0, 122]
# ['alpaca_H', '', 9.2e-61, 194.9, 1.8, 0, 122]
# ['pig_H', '', 9.8e-59, 188.4, 2.2, 0, 122]
# ['mouse_H', '', 4.7e-58, 185.8, 0.3, 0, 122]
# ['rabbit_H', '', 2.9e-49, 157.6, 0.5, 2, 122]
# ['cow_H', '', 6.6e-39, 123.9, 0.4, 1, 122]
#
#  ________________________________________
# ANARCI numbered [HUMAN]48:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 6.9e-66
# bitscore : 211.5
# bias : 2.4
# query_start : 0
# query_end : 120
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]48:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 6.9e-66, 211.5, 2.4, 0, 120]
# ['human_H', '', 1.7e-62, 200.4, 1.2, 0, 120]
# ['pig_H', '', 6.9e-62, 198.6, 2.2, 0, 120]
# ['rhesus_H', '', 8e-62, 198.2, 0.9, 0, 120]
# ['mouse_H', '', 8e-58, 185.1, 0.7, 0, 120]
# ['rabbit_H', '', 9.4e-53, 168.8, 1.0, 2, 120]
# ['cow_H', '', 2e-39, 125.5, 1.2, 1, 120]
#
#  ________________________________________
# ANARCI numbered [HUMAN]49:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.3e-68
# bitscore : 220.3
# bias : 3.0
# query_start : 0
# query_end : 118
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]49:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.3e-68, 220.3, 3.0, 0, 118]
# ['pig_H', '', 8.3e-64, 204.8, 3.7, 0, 118]
# ['rhesus_H', '', 1.7e-62, 200.4, 0.8, 0, 118]
# ['human_H', '', 9.5e-62, 198.0, 1.2, 0, 118]
# ['mouse_H', '', 2.5e-57, 183.5, 0.4, 0, 118]
# ['rabbit_H', '', 2.2e-53, 170.9, 1.1, 2, 118]
# ['cow_H', '', 3.6e-41, 131.2, 2.1, 1, 118]
#
#  ________________________________________
# ANARCI numbered [HUMAN]50:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 6.5e-62
# bitscore : 198.6
# bias : 4.1
# query_start : 0
# query_end : 128
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]50:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 6.5e-62, 198.6, 4.1, 0, 128]
# ['human_H', '', 7.9e-59, 188.5, 2.7, 0, 128]
# ['pig_H', '', 4.3e-58, 186.3, 2.3, 0, 128]
# ['rhesus_H', '', 2.7e-57, 183.5, 4.8, 0, 128]
# ['mouse_H', '', 1.2e-54, 174.9, 2.6, 0, 128]
# ['rabbit_H', '', 2.7e-48, 154.4, 0.4, 2, 128]
# ['cow_H', '', 7.1e-36, 114.1, 1.2, 1, 128]
#
#  ________________________________________
# ANARCI numbered [HUMAN]51:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 7.1e-68
# bitscore : 217.9
# bias : 2.3
# query_start : 0
# query_end : 122
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]51:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 7.1e-68, 217.9, 2.3, 0, 122]
# ['pig_H', '', 6e-63, 202.0, 2.8, 0, 122]
# ['human_H', '', 2e-60, 193.7, 0.6, 0, 122]
# ['rhesus_H', '', 7.3e-60, 191.8, 0.4, 0, 122]
# ['mouse_H', '', 8.3e-56, 178.6, 0.1, 0, 122]
# ['rabbit_H', '', 5.2e-52, 166.4, 0.8, 2, 122]
# ['cow_H', '', 1e-39, 126.5, 1.3, 1, 122]
#
#  ________________________________________
# ANARCI numbered [HUMAN]52:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.5e-61
# bitscore : 197.5
# bias : 5.4
# query_start : 0
# query_end : 126
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]52:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.5e-61, 197.5, 5.4, 0, 126]
# ['human_H', '', 1.4e-59, 190.9, 3.0, 0, 126]
# ['pig_H', '', 5e-59, 189.3, 5.5, 0, 126]
# ['rhesus_H', '', 1.2e-58, 187.9, 3.3, 0, 126]
# ['mouse_H', '', 3.6e-55, 176.5, 2.4, 0, 126]
# ['rabbit_H', '', 5e-50, 160.0, 1.4, 2, 126]
# ['cow_H', '', 5.9e-37, 117.5, 2.2, 1, 126]
#
#  ________________________________________
# ANARCI numbered [HUMAN]53:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.8e-67
# bitscore : 216.6
# bias : 4.0
# query_start : 0
# query_end : 122
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]53:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.8e-67, 216.6, 4.0, 0, 122]
# ['pig_H', '', 4.1e-63, 202.5, 4.4, 0, 122]
# ['human_H', '', 2.6e-61, 196.6, 1.8, 0, 122]
# ['rhesus_H', '', 1.8e-60, 193.8, 1.2, 0, 122]
# ['mouse_H', '', 4.3e-57, 182.8, 0.7, 0, 122]
# ['rabbit_H', '', 2.4e-52, 167.5, 1.2, 2, 122]
# ['cow_H', '', 3.7e-41, 131.1, 1.5, 1, 122]
#
#  ________________________________________
# ANARCI numbered [HUMAN]54:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.6e-65
# bitscore : 210.3
# bias : 1.3
# query_start : 0
# query_end : 118
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]54:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.6e-65, 210.3, 1.3, 0, 118]
# ['rhesus_H', '', 7.3e-63, 201.5, 0.4, 0, 118]
# ['human_H', '', 1.2e-61, 197.6, 0.7, 0, 118]
# ['pig_H', '', 3.5e-59, 189.8, 1.4, 0, 118]
# ['mouse_H', '', 2.5e-57, 183.5, 0.2, 0, 118]
# ['rabbit_H', '', 2.7e-50, 160.9, 0.6, 2, 118]
# ['cow_H', '', 1.8e-37, 119.2, 0.6, 1, 118]
#
#  ________________________________________
# ANARCI numbered [HUMAN]55:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.2e-64
# bitscore : 205.7
# bias : 3.9
# query_start : 0
# query_end : 121
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]55:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.2e-64, 205.7, 3.9, 0, 121]
# ['human_H', '', 3.4e-61, 196.2, 2.0, 0, 121]
# ['rhesus_H', '', 4.2e-61, 195.8, 1.6, 0, 121]
# ['pig_H', '', 2.6e-60, 193.5, 4.5, 0, 121]
# ['mouse_H', '', 8.1e-56, 178.6, 0.9, 0, 121]
# ['rabbit_H', '', 1.6e-51, 164.8, 1.4, 2, 121]
# ['cow_H', '', 1.5e-38, 122.7, 2.0, 1, 121]
#
#  ________________________________________
# ANARCI numbered [HUMAN]56:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2.5e-60
# bitscore : 193.5
# bias : 6.2
# query_start : 0
# query_end : 131
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]56:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2.5e-60, 193.5, 6.2, 0, 131]
# ['human_H', '', 5.6e-57, 182.5, 5.6, 0, 131]
# ['pig_H', '', 1.5e-56, 181.3, 4.2, 0, 131]
# ['rhesus_H', '', 1.3e-54, 174.8, 0.3, 0, 106]
# ['mouse_H', '', 4.9e-53, 169.6, 5.4, 0, 131]
# ['rabbit_H', '', 5.9e-47, 150.1, 1.6, 2, 131]
# ['cow_H', '', 7.1e-35, 110.8, 1.7, 1, 131]
#
#  ________________________________________
# ANARCI numbered [HUMAN]57:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.5e-63
# bitscore : 202.4
# bias : 3.7
# query_start : 0
# query_end : 122
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]57:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.5e-63, 202.4, 3.7, 0, 122]
# ['human_H', '', 2.2e-60, 193.5, 1.9, 0, 122]
# ['pig_H', '', 2.6e-60, 193.5, 4.2, 0, 122]
# ['rhesus_H', '', 7.1e-60, 191.9, 1.4, 0, 122]
# ['mouse_H', '', 1.9e-56, 180.7, 1.1, 0, 122]
# ['rabbit_H', '', 1.2e-50, 162.0, 0.9, 2, 122]
# ['cow_H', '', 5.5e-38, 120.9, 1.5, 1, 122]
#
#  ________________________________________
# ANARCI numbered [HUMAN]58:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.4e-63
# bitscore : 204.0
# bias : 3.2
# query_start : 0
# query_end : 119
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]58:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.4e-63, 204.0, 3.2, 0, 119]
# ['pig_H', '', 3.3e-61, 196.4, 3.2, 0, 119]
# ['human_H', '', 3.6e-61, 196.1, 1.8, 0, 119]
# ['rhesus_H', '', 1.1e-60, 194.5, 1.3, 0, 119]
# ['mouse_H', '', 1.1e-56, 181.4, 1.2, 0, 119]
# ['rabbit_H', '', 1.6e-51, 164.9, 0.9, 2, 119]
# ['cow_H', '', 8.3e-39, 123.5, 1.6, 1, 119]
#
#  ________________________________________
# ANARCI numbered [HUMAN]59:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2.6e-58
# bitscore : 187.0
# bias : 9.4
# query_start : 0
# query_end : 129
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]59:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2.6e-58, 187.0, 9.4, 0, 129]
# ['human_H', '', 2.1e-56, 180.7, 6.1, 0, 129]
# ['pig_H', '', 3.6e-56, 180.1, 8.1, 0, 129]
# ['rhesus_H', '', 2.6e-55, 177.1, 6.9, 0, 129]
# ['mouse_H', '', 8.8e-52, 165.6, 6.2, 0, 129]
# ['rabbit_H', '', 1.4e-47, 152.2, 3.2, 2, 129]
# ['cow_H', '', 2.4e-34, 109.1, 5.0, 1, 129]
#
#  ________________________________________
# ANARCI numbered [HUMAN]60:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 5.9e-70
# bitscore : 224.6
# bias : 2.9
# query_start : 0
# query_end : 120
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]60:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 5.9e-70, 224.6, 2.9, 0, 120]
# ['pig_H', '', 6.8e-65, 208.3, 3.0, 0, 120]
# ['human_H', '', 2e-63, 203.4, 1.4, 0, 120]
# ['rhesus_H', '', 1.8e-62, 200.3, 0.9, 0, 120]
# ['mouse_H', '', 6.7e-59, 188.6, 0.5, 0, 120]
# ['rabbit_H', '', 3.9e-54, 173.3, 1.2, 2, 120]
# ['cow_H', '', 4.5e-42, 134.1, 1.7, 1, 120]
#
#  ________________________________________
# ANARCI numbered [HUMAN]61:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 5.3e-63
# bitscore : 202.2
# bias : 2.5
# query_start : 0
# query_end : 125
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]61:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 5.3e-63, 202.2, 2.5, 0, 125]
# ['human_H', '', 1.2e-60, 194.4, 1.5, 0, 125]
# ['rhesus_H', '', 5.9e-60, 192.1, 1.2, 0, 125]
# ['pig_H', '', 1.3e-59, 191.2, 2.4, 0, 125]
# ['mouse_H', '', 3.4e-56, 179.8, 0.7, 0, 125]
# ['rabbit_H', '', 2.1e-50, 161.3, 0.8, 2, 125]
# ['cow_H', '', 9.4e-38, 120.1, 2.0, 1, 125]
#
#  ________________________________________
# ANARCI numbered [HUMAN]62:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 7.2e-65
# bitscore : 208.2
# bias : 0.8
# query_start : 0
# query_end : 121
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]62:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 7.2e-65, 208.2, 0.8, 0, 121]
# ['human_H', '', 2.4e-60, 193.4, 0.2, 0, 121]
# ['rhesus_H', '', 3.4e-59, 189.7, 0.2, 0, 121]
# ['pig_H', '', 5.7e-58, 185.9, 1.5, 0, 121]
# ['mouse_H', '', 1.9e-55, 177.5, 0.1, 0, 121]
# ['rabbit_H', '', 5.8e-49, 156.6, 0.1, 2, 121]
# ['cow_H', '', 8.7e-40, 126.7, 0.2, 1, 121]
#
#  ________________________________________
# ANARCI numbered [HUMAN]63:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.5e-63
# bitscore : 202.4
# bias : 0.8
# query_start : 0
# query_end : 115
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]63:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.5e-63, 202.4, 0.8, 0, 115]
# ['rhesus_H', '', 8.1e-59, 188.5, 0.2, 0, 115]
# ['human_H', '', 1.1e-58, 188.1, 0.3, 0, 115]
# ['pig_H', '', 8.2e-57, 182.1, 1.1, 0, 115]
# ['mouse_H', '', 6.3e-54, 172.5, 0.1, 0, 115]
# ['rabbit_H', '', 2.2e-47, 151.5, 0.2, 2, 115]
# ['cow_H', '', 4.5e-38, 121.2, 0.3, 1, 115]
#
#  ________________________________________
# ANARCI numbered [HUMAN]64:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 5.4e-68
# bitscore : 218.3
# bias : 3.2
# query_start : 0
# query_end : 123
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]64:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 5.4e-68, 218.3, 3.2, 0, 123]
# ['pig_H', '', 1.6e-62, 200.6, 4.2, 0, 123]
# ['human_H', '', 1.3e-61, 197.5, 1.2, 0, 123]
# ['rhesus_H', '', 6e-61, 195.3, 0.8, 0, 123]
# ['mouse_H', '', 5.7e-57, 182.3, 0.3, 0, 123]
# ['rabbit_H', '', 1.2e-52, 168.5, 1.0, 2, 123]
# ['cow_H', '', 2.1e-40, 128.7, 2.1, 1, 123]
#
#  ________________________________________
# ANARCI numbered [HUMAN]65:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 5.2e-62
# bitscore : 199.0
# bias : 3.5
# query_start : 0
# query_end : 124
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]65:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 5.2e-62, 199.0, 3.5, 0, 124]
# ['pig_H', '', 1.1e-58, 188.3, 3.7, 0, 124]
# ['human_H', '', 4.4e-57, 182.9, 4.1, 0, 124]
# ['rhesus_H', '', 6.5e-55, 175.8, 6.8, 0, 124]
# ['mouse_H', '', 2.1e-52, 167.6, 4.0, 0, 124]
# ['rabbit_H', '', 2.4e-49, 157.8, 0.9, 2, 124]
# ['cow_H', '', 8.5e-38, 120.3, 1.0, 1, 124]
#
#  ________________________________________
# ANARCI numbered [HUMAN]66:0.6:H
# It identified 1 domain(s)
# id : human_H
# description :
# evalue : 1.4e-54
# bitscore : 174.8
# bias : 2.6
# query_start : 0
# query_end : 127
# species : human
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]66:0.6:H
# ...
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]305:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.2e-63, 204.3, 2.3, 0, 119]
# ['pig_H', '', 2.1e-60, 193.8, 2.3, 0, 119]
# ['human_H', '', 3.4e-60, 192.9, 1.2, 0, 119]
# ['rhesus_H', '', 4.7e-60, 192.5, 1.0, 0, 119]
# ['mouse_H', '', 3.9e-56, 179.6, 0.5, 0, 119]
# ['rabbit_H', '', 9.4e-51, 162.4, 0.7, 2, 119]
# ['cow_H', '', 1.8e-37, 119.2, 2.1, 1, 119]
#
#  ________________________________________
# ANARCI numbered [HUMAN]306:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2e-64
# bitscore : 206.8
# bias : 3.4
# query_start : 0
# query_end : 122
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]306:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2e-64, 206.8, 3.4, 0, 122]
# ['human_H', '', 4.1e-60, 192.7, 1.6, 0, 122]
# ['rhesus_H', '', 1.3e-59, 191.0, 1.1, 0, 122]
# ['pig_H', '', 3.5e-58, 186.6, 4.0, 0, 122]
# ['mouse_H', '', 1.3e-55, 178.0, 0.6, 0, 122]
# ['rabbit_H', '', 1.2e-48, 155.6, 0.9, 2, 122]
# ['cow_H', '', 3e-36, 115.3, 1.5, 1, 122]
#
#  ________________________________________
# ANARCI numbered [HUMAN]307:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 3.8e-64
# bitscore : 205.9
# bias : 3.0
# query_start : 0
# query_end : 124
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]307:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 3.8e-64, 205.9, 3.0, 0, 124]
# ['human_H', '', 5.4e-61, 195.5, 1.1, 0, 124]
# ['rhesus_H', '', 1.3e-60, 194.3, 0.9, 0, 124]
# ['pig_H', '', 4.2e-60, 192.8, 3.0, 0, 124]
# ['mouse_H', '', 2e-56, 180.6, 1.0, 0, 124]
# ['rabbit_H', '', 2.2e-51, 164.4, 0.5, 2, 124]
# ['cow_H', '', 2.9e-38, 121.8, 0.8, 1, 124]
#
#  ________________________________________
# ANARCI numbered [HUMAN]308:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.6e-62
# bitscore : 200.6
# bias : 1.1
# query_start : 0
# query_end : 113
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]308:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.6e-62, 200.6, 1.1, 0, 113]
# ['rhesus_H', '', 7.1e-60, 191.9, 0.5, 0, 113]
# ['human_H', '', 2.8e-59, 190.0, 0.6, 0, 113]
# ['pig_H', '', 2.4e-58, 187.1, 1.1, 0, 113]
# ['mouse_H', '', 3e-54, 173.6, 0.2, 0, 113]
# ['rabbit_H', '', 4.3e-49, 157.0, 0.2, 2, 113]
# ['cow_H', '', 1.9e-35, 112.7, 0.4, 1, 113]
#
#  ________________________________________
# ANARCI numbered [HUMAN]309:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.4e-61
# bitscore : 197.6
# bias : 5.3
# query_start : 0
# query_end : 129
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]309:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.4e-61, 197.6, 5.3, 0, 129]
# ['human_H', '', 1e-57, 185.0, 4.3, 0, 129]
# ['pig_H', '', 5.9e-57, 182.6, 4.4, 0, 129]
# ['rhesus_H', '', 3.3e-56, 180.0, 6.1, 0, 129]
# ['mouse_H', '', 1e-52, 168.6, 4.9, 0, 129]
# ['rabbit_H', '', 7e-47, 149.9, 1.6, 2, 129]
# ['cow_H', '', 9.4e-36, 113.7, 2.8, 1, 129]
#
#  ________________________________________
# ANARCI numbered [HUMAN]310:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 5.9e-65
# bitscore : 208.5
# bias : 2.9
# query_start : 0
# query_end : 118
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]310:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 5.9e-65, 208.5, 2.9, 0, 118]
# ['rhesus_H', '', 3.7e-62, 199.3, 1.1, 0, 118]
# ['human_H', '', 2.6e-61, 196.5, 1.4, 0, 118]
# ['pig_H', '', 2.3e-59, 190.4, 3.1, 0, 118]
# ['mouse_H', '', 3.4e-57, 183.1, 0.8, 0, 118]
# ['rabbit_H', '', 1.6e-50, 161.6, 0.5, 2, 118]
# ['cow_H', '', 1.3e-37, 119.6, 0.9, 1, 118]
#
#  ________________________________________
# ANARCI numbered [HUMAN]311:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 4.2e-63
# bitscore : 202.5
# bias : 3.1
# query_start : 0
# query_end : 125
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]311:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 4.2e-63, 202.5, 3.1, 0, 125]
# ['human_H', '', 6.3e-60, 192.1, 2.0, 0, 125]
# ['rhesus_H', '', 2.9e-59, 189.9, 1.5, 0, 125]
# ['pig_H', '', 7.6e-59, 188.7, 2.7, 0, 125]
# ['mouse_H', '', 4.2e-56, 179.5, 1.5, 0, 125]
# ['rabbit_H', '', 3.7e-49, 157.2, 0.4, 2, 125]
# ['cow_H', '', 4.7e-37, 117.9, 0.6, 1, 125]
#
#  ________________________________________
# ANARCI numbered [HUMAN]312:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.2e-65
# bitscore : 210.7
# bias : 0.8
# query_start : 0
# query_end : 120
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]312:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.2e-65, 210.7, 0.8, 0, 120]
# ['human_H', '', 3.1e-61, 196.3, 0.3, 0, 120]
# ['rhesus_H', '', 7.9e-61, 194.9, 0.2, 0, 120]
# ['pig_H', '', 7.2e-59, 188.8, 1.1, 0, 120]
# ['mouse_H', '', 9e-57, 181.7, 0.1, 0, 120]
# ['rabbit_H', '', 6.6e-50, 159.6, 0.1, 2, 120]
# ['cow_H', '', 2.1e-37, 119.0, 0.2, 1, 120]
#
#  ________________________________________
# ANARCI numbered [HUMAN]313:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 5.5e-60
# bitscore : 192.4
# bias : 7.6
# query_start : 0
# query_end : 131
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]313:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 5.5e-60, 192.4, 7.6, 0, 131]
# ['pig_H', '', 2.6e-57, 183.8, 6.2, 0, 131]
# ['human_H', '', 3.5e-57, 183.2, 4.8, 0, 131]
# ['rhesus_H', '', 4.1e-56, 179.7, 5.9, 0, 131]
# ['mouse_H', '', 3.9e-52, 166.7, 6.2, 0, 131]
# ['rabbit_H', '', 3.6e-48, 154.0, 1.6, 2, 131]
# ['cow_H', '', 3.6e-35, 111.8, 4.2, 1, 131]
#
#  ________________________________________
# ANARCI numbered [HUMAN]314:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 3.8e-59
# bitscore : 189.7
# bias : 9.6
# query_start : 0
# query_end : 129
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]314:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 3.8e-59, 189.7, 9.6, 0, 129]
# ['pig_H', '', 3.4e-57, 183.4, 7.7, 0, 129]
# ['human_H', '', 5.6e-57, 182.5, 7.6, 0, 129]
# ['rhesus_H', '', 4.9e-56, 179.5, 7.9, 0, 129]
# ['mouse_H', '', 3.1e-52, 167.1, 7.5, 0, 129]
# ['rabbit_H', '', 1.5e-47, 152.0, 3.9, 2, 129]
# ['cow_H', '', 1.2e-35, 113.4, 5.6, 1, 129]
#
#  ________________________________________
# ANARCI numbered [HUMAN]315:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 3.6e-69
# bitscore : 222.1
# bias : 4.6
# query_start : 0
# query_end : 119
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]315:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 3.6e-69, 222.1, 4.6, 0, 119]
# ['pig_H', '', 5.4e-64, 205.4, 5.0, 0, 119]
# ['human_H', '', 8.1e-63, 201.4, 2.5, 0, 119]
# ['rhesus_H', '', 1.5e-62, 200.6, 1.8, 0, 119]
# ['mouse_H', '', 4.1e-58, 186.1, 1.1, 0, 119]
# ['rabbit_H', '', 1.2e-53, 171.7, 1.9, 2, 119]
# ['cow_H', '', 2.1e-41, 131.9, 2.7, 1, 119]
#
#  ________________________________________
# ANARCI numbered [HUMAN]316:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.7e-65
# bitscore : 210.3
# bias : 4.6
# query_start : 0
# query_end : 128
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]316:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.7e-65, 210.3, 4.6, 0, 128]
# ['pig_H', '', 3.1e-61, 196.5, 4.7, 0, 128]
# ['human_H', '', 2.2e-59, 190.3, 2.0, 0, 128]
# ['rhesus_H', '', 1.1e-57, 184.8, 4.0, 0, 128]
# ['mouse_H', '', 5.1e-55, 176.0, 1.0, 0, 128]
# ['rabbit_H', '', 2.1e-50, 161.3, 1.3, 2, 128]
# ['cow_H', '', 4.1e-39, 124.5, 2.1, 1, 128]
#
#  ________________________________________
# ANARCI numbered [HUMAN]317:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.3e-62
# bitscore : 201.0
# bias : 10.7
# query_start : 0
# query_end : 132
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]317:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.3e-62, 201.0, 10.7, 0, 132]
# ['pig_H', '', 5.3e-59, 189.2, 8.7, 0, 132]
# ['human_H', '', 9.3e-57, 181.8, 7.1, 0, 132]
# ['rhesus_H', '', 1.4e-55, 178.0, 7.2, 0, 132]
# ['mouse_H', '', 3.4e-52, 166.9, 6.3, 0, 132]
# ['rabbit_H', '', 2.4e-48, 154.6, 4.5, 2, 132]
# ['cow_H', '', 3.7e-37, 118.2, 6.2, 1, 132]
#
#  ________________________________________
# ANARCI numbered [HUMAN]318:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 2.2e-61
# bitscore : 196.9
# bias : 5.9
# query_start : 0
# query_end : 126
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]318:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 2.2e-61, 196.9, 5.9, 0, 126]
# ['human_H', '', 2.5e-59, 190.1, 3.6, 0, 126]
# ['pig_H', '', 7.8e-59, 188.7, 6.0, 0, 126]
# ['rhesus_H', '', 9.2e-59, 188.3, 2.9, 0, 126]
# ['mouse_H', '', 2.9e-55, 176.8, 2.6, 0, 126]
# ['rabbit_H', '', 8.8e-50, 159.2, 1.9, 2, 126]
# ['cow_H', '', 1.6e-36, 116.2, 3.6, 1, 126]
#
#  ________________________________________
# ANARCI numbered [HUMAN]319:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 6.7e-64
# bitscore : 205.1
# bias : 1.0
# query_start : 0
# query_end : 124
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]319:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 6.7e-64, 205.1, 1.0, 0, 124]
# ['human_H', '', 6.1e-61, 195.4, 0.5, 0, 124]
# ['rhesus_H', '', 2.5e-60, 193.3, 0.4, 0, 124]
# ['pig_H', '', 6.5e-59, 189.0, 1.3, 0, 124]
# ['mouse_H', '', 5.5e-56, 179.2, 0.2, 0, 124]
# ['rabbit_H', '', 7.6e-50, 159.4, 0.2, 2, 124]
# ['cow_H', '', 3.2e-37, 118.4, 0.2, 1, 124]
#
#  ________________________________________
# ANARCI numbered [HUMAN]320:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.1e-62
# bitscore : 201.1
# bias : 4.0
# query_start : 0
# query_end : 121
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]320:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.1e-62, 201.1, 4.0, 0, 121]
# ['human_H', '', 7.1e-60, 191.9, 2.0, 0, 121]
# ['rhesus_H', '', 3e-59, 189.8, 1.5, 0, 121]
# ['pig_H', '', 4.6e-59, 189.4, 4.2, 0, 121]
# ['mouse_H', '', 4.9e-55, 176.1, 1.5, 0, 121]
# ['rabbit_H', '', 8.2e-50, 159.3, 0.8, 2, 121]
# ['cow_H', '', 3.2e-37, 118.4, 2.0, 1, 121]
#
#  ________________________________________
# ANARCI numbered [HUMAN]321:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 6.6e-62
# bitscore : 198.6
# bias : 2.5
# query_start : 0
# query_end : 124
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]321:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 6.6e-62, 198.6, 2.5, 0, 124]
# ['human_H', '', 8.6e-60, 191.6, 1.4, 0, 124]
# ['rhesus_H', '', 5.5e-59, 189.0, 0.9, 0, 124]
# ['pig_H', '', 2.4e-57, 183.9, 2.8, 0, 124]
# ['mouse_H', '', 6e-56, 179.0, 0.7, 0, 124]
# ['rabbit_H', '', 3.6e-49, 157.3, 1.4, 2, 124]
# ['cow_H', '', 1.2e-38, 123.0, 1.4, 1, 124]
#
#  ________________________________________
# ANARCI numbered [HUMAN]322:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.2e-63
# bitscore : 204.3
# bias : 3.0
# query_start : 0
# query_end : 123
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]322:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.2e-63, 204.3, 3.0, 0, 123]
# ['human_H', '', 1.3e-60, 194.3, 1.5, 0, 123]
# ['rhesus_H', '', 6.4e-60, 192.0, 1.2, 0, 123]
# ['pig_H', '', 2.8e-59, 190.2, 3.0, 0, 123]
# ['mouse_H', '', 1.3e-56, 181.2, 0.9, 0, 123]
# ['rabbit_H', '', 1.1e-49, 158.9, 0.4, 2, 123]
# ['cow_H', '', 2.6e-37, 118.7, 0.8, 1, 123]
#
#  ________________________________________
# ANARCI numbered [HUMAN]323:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.5e-62
# bitscore : 200.7
# bias : 2.9
# query_start : 0
# query_end : 115
# species : alpaca
# chain_type : H
# scheme : imgt
# query_name : [HUMAN]323:0.6:H
# This is the summary of the hits that HMMER found
# ['id', 'description', 'evalue', 'bitscore', 'bias', 'query_start', 'query_end']
# ['alpaca_H', '', 1.5e-62, 200.7, 2.9, 0, 115]
# ['rhesus_H', '', 4.3e-60, 192.6, 1.1, 0, 115]
# ['human_H', '', 2.5e-59, 190.1, 1.4, 0, 115]
# ['pig_H', '', 4.3e-59, 189.5, 3.4, 0, 115]
# ['mouse_H', '', 2.6e-55, 177.0, 0.8, 0, 115]
# ['rabbit_H', '', 7.1e-50, 159.5, 0.8, 2, 115]
# ['cow_H', '', 1.1e-36, 116.6, 1.7, 1, 115]
#
#  ________________________________________
# ANARCI numbered [HUMAN]324:0.6:H
# It identified 1 domain(s)
# id : alpaca_H
# description :
# evalue : 1.7e-62
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[90], line 19
#      15 # print('This is the IMGT numbering for the %d\'th domain:'%j, domain_numbering)
#      16 # print('This is the bit of the sequence it corresponds to:', anarci_sequences[i][1][start_index:end_index+1])
#      17 # print('These are the details of the alignment:')
#      18 for (key,value) in alignment_details[i][j].items():
# ---> 19     print(key, ':', value)
#      20 print('This is the summary of the hits that HMMER found')
#      21 for line in hit_tables[i]:
#
# File ~/opt/anaconda3/envs/iglm/lib/python3.10/site-packages/ipykernel/iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File ~/opt/anaconda3/envs/iglm/lib/python3.10/site-packages/ipykernel/iostream.py:216, in IOPubThread.schedule(self, f)
#     214     self._events.append(f)
#     215     # wake event thread (message content is ignored)
# --> 216     self._event_pipe.send(b'')
#     217 else:
#     218     f()
#
# File ~/opt/anaconda3/envs/iglm/lib/python3.10/site-packages/zmq/sugar/socket.py:618, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     611         data = zmq.Frame(
#     612             data,
#     613             track=track,
#     614             copy=copy or None,
#     615             copy_threshold=self.copy_threshold,
#     616         )
#     617     data.group = group
# --> 618 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/socket.pyx:740, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:787, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:244, in zmq.backend.cython.socket._send_copy()
#
# File ~/opt/anaconda3/envs/iglm/lib/python3.10/site-packages/zmq/backend/cython/checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
